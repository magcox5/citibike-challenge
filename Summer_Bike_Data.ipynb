# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
# Files for 1 year's worth of data from monthly bike data 
bike_data = {}
#bike_data[1] = "Data/202002-citibike-tripdata.csv"
#bike_data[2] = "Data/202001-citibike-tripdata.csv"
#bike_data[3] = "Data/201912-citibike-tripdata.csv"
#bike_data[4] = "Data/201911-citibike-tripdata.csv"
#bike_data[5] = "Data/201910-citibike-tripdata.csv"
#bike_data[6] = "Data/201909-citibike-tripdata.csv"
bike_data[7] = "Data/201908-citibike-tripdata.csv"
bike_data[8] = "Data/201907-citibike-tripdata.csv"
bike_data[9] = "Data/201906-citibike-tripdata.csv"
#bike_data[10] = "Data/201905-citibike-tripdata.csv"
#bike_data[11]= "Data/201904-citibike-tripdata.csv"
#bike_data[12] = "Data/201903-citibike-tripdata.csv"

# Read City bike data from monthly files
bike = {}
#bike[1] = pd.read_csv(bike_data[1])
#bike[2] = pd.read_csv(bike_data[2])
#bike[3] = pd.read_csv(bike_data[3])
#bike[4] = pd.read_csv(bike_data[4])
#bike[5] = pd.read_csv(bike_data[5])
#bike[6] = pd.read_csv(bike_data[6])
bike[7] = pd.read_csv(bike_data[7])
bike[8] = pd.read_csv(bike_data[8])
bike[9] = pd.read_csv(bike_data[9])
#bike[10] = pd.read_csv(bike_data[10])
#bike[11] = pd.read_csv(bike_data[11])
#bike[12] = pd.read_csv(bike_data[12])

# %%
bike_months = {}
bike_years = {}
for i in range(7,10):
    bike_months[i] = bike_data[i][9:11]
    bike_years[i] = bike_data[i][5:9]
    print(i, bike_data[i], bike_months[i], bike_years[i])
# Out:
# 7 Data/201908-citibike-tripdata.csv 08 2019
# 8 Data/201907-citibike-tripdata.csv 07 2019
# 9 Data/201906-citibike-tripdata.csv 06 2019

# %%
# Add a month and year column to each dataframe
for i in range(7,10):
    bike[i]['Month'] = bike_months[i]
    bike[i]['Year'] = bike_years[i]
    bike[i]['time_minutes'] = round(bike[i]['tripduration']/60)

# %%
bike[8]
# Out:
#          tripduration                 starttime                  stoptime  start station id              start station name  start station latitude  start station longitude  end station id             end station name  end station latitude  end station longitude  bikeid    usertype  birth year  gender Month  Year  time_minutes
# 0                 897  2019-07-01 00:00:00.1320  2019-07-01 00:14:58.0040             493.0                 W 45 St & 6 Ave               40.756800               -73.982912           454.0              E 51 St & 1 Ave             40.754557             -73.965930   18340  Subscriber        1966       1    07  2019          15.0
# 1                 267  2019-07-01 00:00:05.1780  2019-07-01 00:04:32.4500            3143.0                 5 Ave & E 78 St               40.776321               -73.964274          3226.0  W 82 St & Central Park West             40.782750             -73.971370   21458    Customer        1996       1    07  2019           4.0
# ...

# %%
# Combine all dataframes into 1 .csv
combined_bikes = pd.concat([bike[7], bike[8], bike[9]])
combined_bikes
# Out:
#          tripduration                 starttime                  stoptime  start station id              start station name  start station latitude  start station longitude  end station id              end station name  end station latitude  end station longitude  bikeid    usertype  birth year  gender Month  Year  time_minutes
# 0                 393  2019-08-01 00:00:01.4680  2019-08-01 00:06:35.3780             531.0          Forsyth St & Broome St               40.718939               -73.992663           408.0         Market St & Cherry St             40.710762             -73.994004   35305  Subscriber        1996       2    08  2019           7.0
# 1                 627  2019-08-01 00:00:01.9290  2019-08-01 00:10:29.7840             274.0  Lafayette Ave & Fort Greene Pl               40.686919               -73.976682          3409.0          Bergen St & Smith St             40.686744             -73.990632   38822  Subscriber        1998       2    08  2019          10.0
# ...

# %%
combined_bikes.to_csv('Data/nyc_bike_data.csv', index=False)

# %%
unique_bikes = combined_bikes['bikeid'].nunique()

# %%
print(unique_bikes)
# Out:
# 14934
